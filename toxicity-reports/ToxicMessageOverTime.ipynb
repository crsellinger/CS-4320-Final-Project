# %%
###This metric shows the percentage of toxic messages per month in a repo###
import psycopg2
import pandas as pd 
import sqlalchemy as salc
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import datetime
import json
warnings.filterwarnings('ignore')

with open("config.json") as config_file:
    config = json.load(config_file)

database_connection_string = 'postgres+psycopg2://{}:{}@{}:{}/{}'.format(config['user'], config['password'], config['host'], config['port'], config['database'])

dbschema='augur_data'
engine = salc.create_engine(
    database_connection_string,
    connect_args={'options': '-csearch_path={}'.format(dbschema)})

# %%
###USER PICKS REPO TO MEASURE THIS METRIC###
repoName = input("input repo name:")

# %%
###This gathers the average sentiment scores for every message in the history of the repo and orders them by month###
repolist = pd.DataFrame()

repo_query = salc.sql.text(f"""
            SELECT
                repo.repo_id,
                repo.repo_name,
                date_trunc( 'month', message.msg_timestamp ) AS message_month,
                message.cntrb_id, 
                AVG ( message_analysis.sentiment_score ) AS average_sentiment
            FROM
                repo, message_analysis, message, issue_message_ref, issues 
                where message_analysis.msg_id = message.msg_id 
                and 
                issue_message_ref.issue_id = issues.issue_id  
                AND
                issue_message_ref.msg_id = message.msg_id 
                AND
                issues.repo_id = repo.repo_id 
                AND
                repo.repo_name = '""" + repoName + """'
            GROUP BY
                repo.repo_id,
                repo.repo_name,
                message.msg_timestamp, 
                message.cntrb_id 
            ORDER BY
                message_month ASC,
                average_sentiment DESC,
                repo_id;
    """)

repolist = pd.read_sql(repo_query, con=engine)

display(repolist)

repolist.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-7baa314e3bcc> in <module>
#      19                 issues.repo_id = repo.repo_id
#      20                 AND
# ---> 21                 repo.repo_name = '""" + repoName + """'
#      22             GROUP BY
#      23                 repo.repo_id,
#
# NameError: name 'repoName' is not defined

# %%
###This gathers all the possible months to be used for calculating percentages###
repolist2 = pd.DataFrame()

repo_query2 = salc.sql.text(f"""
            SELECT DISTINCT
                repo.repo_id,
                repo.repo_name,
                date_trunc( 'month', message.msg_timestamp ) AS message_month
            FROM
                repo, message_analysis, message, issue_message_ref, issues 
                where message_analysis.msg_id = message.msg_id 
                AND
                issue_message_ref.issue_id = issues.issue_id  
                AND
                issue_message_ref.msg_id = message.msg_id 
                AND
                issues.repo_id = repo.repo_id 
                AND
                repo.repo_name = '""" + repoName + """'
            GROUP BY
                repo.repo_id,
                repo.repo_name, 
                message.msg_timestamp
            ORDER BY
                message_month;
    """)

repolist2 = pd.read_sql(repo_query2, con=engine)

display(repolist2)

repolist2.dtypes
# Out:
#      repo_id repo_name message_month
# 0      26188     Loris    2011-11-01
# 1      26188     Loris    2011-12-01
# 2      26188     Loris    2012-01-01
# 3      26188     Loris    2012-02-01
# 4      26188     Loris    2012-04-01
# ..       ...       ...           ...
# 102    26188     Loris    2020-06-01
# 103    26188     Loris    2020-07-01
# 104    26188     Loris    2020-08-01
# 105    26188     Loris    2020-09-01
# 106    26188     Loris    2020-10-01
#
# [107 rows x 3 columns]
# repo_id                   int64
# repo_name                object
# message_month    datetime64[ns]
# dtype: object

# %%
###This calculates the percent of toxic messages per month and stores each month's average in an array###
percent_by_month_array = np.zeros(len(repolist2.message_month))
monthYearLabel = []
i = 0
j = 0
while i < len(repolist2.message_month):
    month = repolist2.message_month[i]
    toxic_messages = 0
    total_messages = 0 #total messages for each month
    while repolist.message_month[j] == month:
        if repolist.average_sentiment[j] < 0:
            toxic_messages = toxic_messages + 1
        total_messages = total_messages + 1
        j = j + 1
        if j >= len(repolist.message_month):
            break
    toxic_percent = toxic_messages/total_messages  #get average for that month
    percent_by_month_array[i] = toxic_percent * 100
    print("total messages for month:", repolist2.message_month[i], ":",  total_messages)
    monthYearLabel.append(repolist2.message_month[i].to_pydatetime().strftime("%B %Y"))
    i = i + 1
# Out:
# total messages for month: 2011-11-01 00:00:00 : 1
# total messages for month: 2011-12-01 00:00:00 : 3
# total messages for month: 2012-01-01 00:00:00 : 6
# total messages for month: 2012-02-01 00:00:00 : 1
# total messages for month: 2012-04-01 00:00:00 : 5
# total messages for month: 2012-05-01 00:00:00 : 14
# total messages for month: 2012-06-01 00:00:00 : 5
# total messages for month: 2012-07-01 00:00:00 : 10
# total messages for month: 2012-08-01 00:00:00 : 8
# total messages for month: 2012-09-01 00:00:00 : 5
# total messages for month: 2012-10-01 00:00:00 : 1
# total messages for month: 2012-11-01 00:00:00 : 13
# total messages for month: 2012-12-01 00:00:00 : 6
# total messages for month: 2013-01-01 00:00:00 : 9
# total messages for month: 2013-02-01 00:00:00 : 7
# total messages for month: 2013-03-01 00:00:00 : 6
# total messages for month: 2013-04-01 00:00:00 : 8
# total messages for month: 2013-05-01 00:00:00 : 3
# total messages for month: 2013-06-01 00:00:00 : 9
# total messages for month: 2013-07-01 00:00:00 : 5
# total messages for month: 2013-08-01 00:00:00 : 8
# total messages for month: 2013-09-01 00:00:00 : 4
# total messages for month: 2013-10-01 00:00:00 : 1
# total messages for month: 2013-11-01 00:00:00 : 3
# total messages for month: 2013-12-01 00:00:00 : 1
# total messages for month: 2014-01-01 00:00:00 : 9
# total messages for month: 2014-02-01 00:00:00 : 3
# total messages for month: 2014-03-01 00:00:00 : 6
# total messages for month: 2014-04-01 00:00:00 : 3
# total messages for month: 2014-05-01 00:00:00 : 7
# total messages for month: 2014-06-01 00:00:00 : 14
# total messages for month: 2014-07-01 00:00:00 : 3
# total messages for month: 2014-08-01 00:00:00 : 3
# total messages for month: 2014-09-01 00:00:00 : 18
# total messages for month: 2014-10-01 00:00:00 : 27
# total messages for month: 2014-11-01 00:00:00 : 10
# total messages for month: 2014-12-01 00:00:00 : 4
# total messages for month: 2015-01-01 00:00:00 : 18
# total messages for month: 2015-02-01 00:00:00 : 23
# total messages for month: 2015-03-01 00:00:00 : 31
# total messages for month: 2015-04-01 00:00:00 : 40
# total messages for month: 2015-05-01 00:00:00 : 22
# total messages for month: 2015-06-01 00:00:00 : 33
# total messages for month: 2015-07-01 00:00:00 : 54
# total messages for month: 2015-08-01 00:00:00 : 27
# total messages for month: 2015-09-01 00:00:00 : 42
# total messages for month: 2015-10-01 00:00:00 : 37
# total messages for month: 2015-11-01 00:00:00 : 41
# total messages for month: 2015-12-01 00:00:00 : 39
# total messages for month: 2016-01-01 00:00:00 : 67
# total messages for month: 2016-02-01 00:00:00 : 55
# total messages for month: 2016-03-01 00:00:00 : 169
# total messages for month: 2016-04-01 00:00:00 : 132
# total messages for month: 2016-05-01 00:00:00 : 102
# total messages for month: 2016-06-01 00:00:00 : 182
# total messages for month: 2016-07-01 00:00:00 : 152
# total messages for month: 2016-08-01 00:00:00 : 141
# total messages for month: 2016-09-01 00:00:00 : 187
# total messages for month: 2016-10-01 00:00:00 : 146
# total messages for month: 2016-11-01 00:00:00 : 56
# total messages for month: 2016-12-01 00:00:00 : 58
# total messages for month: 2017-01-01 00:00:00 : 107
# total messages for month: 2017-02-01 00:00:00 : 103
# total messages for month: 2017-03-01 00:00:00 : 227
# total messages for month: 2017-04-01 00:00:00 : 200
# total messages for month: 2017-05-01 00:00:00 : 217
# total messages for month: 2017-06-01 00:00:00 : 340
# total messages for month: 2017-07-01 00:00:00 : 274
# total messages for month: 2017-08-01 00:00:00 : 226
# total messages for month: 2017-09-01 00:00:00 : 38
# total messages for month: 2017-10-01 00:00:00 : 153
# total messages for month: 2017-11-01 00:00:00 : 190
# total messages for month: 2017-12-01 00:00:00 : 104
# total messages for month: 2018-01-01 00:00:00 : 196
# total messages for month: 2018-02-01 00:00:00 : 143
# total messages for month: 2018-03-01 00:00:00 : 223
# total messages for month: 2018-04-01 00:00:00 : 188
# total messages for month: 2018-05-01 00:00:00 : 172
# total messages for month: 2018-06-01 00:00:00 : 168
# total messages for month: 2018-07-01 00:00:00 : 370
# total messages for month: 2018-08-01 00:00:00 : 221
# total messages for month: 2018-09-01 00:00:00 : 146
# total messages for month: 2018-10-01 00:00:00 : 236
# total messages for month: 2018-11-01 00:00:00 : 266
# total messages for month: 2018-12-01 00:00:00 : 213
# total messages for month: 2019-01-01 00:00:00 : 289
# total messages for month: 2019-02-01 00:00:00 : 278
# total messages for month: 2019-03-01 00:00:00 : 294
# total messages for month: 2019-04-01 00:00:00 : 164
# total messages for month: 2019-05-01 00:00:00 : 514
# total messages for month: 2019-06-01 00:00:00 : 448
# total messages for month: 2019-07-01 00:00:00 : 207
# total messages for month: 2019-08-01 00:00:00 : 185
# total messages for month: 2019-09-01 00:00:00 : 254
# total messages for month: 2019-10-01 00:00:00 : 528
# total messages for month: 2019-11-01 00:00:00 : 1063
# total messages for month: 2019-12-01 00:00:00 : 302
# total messages for month: 2020-01-01 00:00:00 : 843
# total messages for month: 2020-02-01 00:00:00 : 542
# total messages for month: 2020-03-01 00:00:00 : 406
# total messages for month: 2020-04-01 00:00:00 : 724
# total messages for month: 2020-05-01 00:00:00 : 685
# total messages for month: 2020-06-01 00:00:00 : 606
# total messages for month: 2020-07-01 00:00:00 : 375
# total messages for month: 2020-08-01 00:00:00 : 293
# total messages for month: 2020-09-01 00:00:00 : 277
# total messages for month: 2020-10-01 00:00:00 : 36

# %%
###This plots the percentage of toxic messages per month
x = list(range(len(repolist2.message_month)))
y = percent_by_month_array


length = len(monthYearLabel)
lower = 0;
upper = min(29, length)
while(upper < len(x)):
    if(lower > upper or lower >= length):
        break
    X = np.arange(len(x[lower:upper]))
    fig = plt.figure(figsize=(30, 10))
    ax = fig.add_axes([0,0,1,1])
    graph = plt.scatter(x[lower:upper], y[lower:upper])
    plt.plot(x[lower:upper],y[lower:upper])
    plt.xticks(x[lower:upper], monthYearLabel[lower:upper], rotation=80, fontsize=25)
    plt.yticks(fontsize=18)
    plt.ylabel("Toxic Message Percentage", fontsize=22)
    plt.xlabel("Month", fontsize=22)
    plt.title("Repo " + repoName + " Monthly Toxic Message Percentage: " + monthYearLabel[lower] + " - " + monthYearLabel[upper], fontsize=30)
    plt.ylim(top=100)
    for i in range(lower, upper):
        plt.text(x[i] - .3, y[i] + 1, "{percent:.2f}%".format(percent= y[i]), fontsize=20)
    plt.show()
    lower = lower + 30
    upper = upper + min(30, length - lower)
