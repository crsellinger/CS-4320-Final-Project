# %%
###This metric shows the number of toxic messages per month for a user in a repo###
import psycopg2
import pandas as pd 
import sqlalchemy as salc
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import datetime
import json
warnings.filterwarnings('ignore')

with open("config.json") as config_file:
    config = json.load(config_file)

database_connection_string = 'postgres+psycopg2://{}:{}@{}:{}/{}'.format(config['user'], config['password'], config['host'], config['port'], config['database'])

dbschema='augur_data'
engine = salc.create_engine(
    database_connection_string,
    connect_args={'options': '-csearch_path={}'.format(dbschema)})

# %%
### USER PICKS SPECIFIC CONTRIBUTER TO MEASURE THIS METRIC###
cntrbID = input("input contributer name:")
# Out:
# input contributer name: 389737

# %%
###This gathers the average sentiment scores for every message in the history of the repo and orders them by month###
repolist = pd.DataFrame()

repo_query = salc.sql.text(f"""
            SELECT
                repo.repo_id,
                repo.repo_name,
                date_trunc( 'month', message.msg_timestamp ) AS message_month,
                message.cntrb_id, 
                AVG ( message_analysis.sentiment_score ) AS average_sentiment
            FROM
                repo, message_analysis, message, issue_message_ref, issues 
                where message_analysis.msg_id = message.msg_id 
                and 
                issue_message_ref.issue_id = issues.issue_id  
                AND
                issue_message_ref.msg_id = message.msg_id 
                AND
                issues.repo_id = repo.repo_id 
                AND
                message.cntrb_id = '""" + cntrbID + """'
                
            GROUP BY
                repo.repo_id,
                repo.repo_name,
                message.msg_timestamp, 
                message.cntrb_id 
            ORDER BY
                message_month ASC,
                average_sentiment DESC,
                repo_id;
    """)

repolist = pd.read_sql(repo_query, con=engine)

display(repolist)

repolist.dtypes
# Out:
#       repo_id repo_name message_month  cntrb_id  average_sentiment
# 0       26188     Loris    2011-11-01    389737           0.000000
# 1       26188     Loris    2011-12-01    389737           0.000000
# 2       26188     Loris    2012-01-01    389737           0.000000
# 3       26188     Loris    2012-01-01    389737           0.000000
# 4       26188     Loris    2012-02-01    389737           0.000000
# ...       ...       ...           ...       ...                ...
# 2566    26188     Loris    2020-09-01    389737          -0.473972
# 2567    26188     Loris    2020-09-01    389737          -0.479040
# 2568    26188     Loris    2020-09-01    389737          -0.510269
# 2569    26188     Loris    2020-10-01    389737           0.000000
# 2570    26188     Loris    2020-10-01    389737           0.000000
#
# [2571 rows x 5 columns]
# repo_id                       int64
# repo_name                    object
# message_month        datetime64[ns]
# cntrb_id                      int64
# average_sentiment           float64
# dtype: object

# %%
###This gathers all the possible months to be used for calculating percentages###
repolist2 = pd.DataFrame()

repo_query2 = salc.sql.text(f"""
            SELECT DISTINCT
                repo.repo_id,
                repo.repo_name,
                date_trunc( 'month', message.msg_timestamp ) AS message_month
            FROM
                repo, message_analysis, message, issue_message_ref, issues 
                where message_analysis.msg_id = message.msg_id 
                AND
                issue_message_ref.issue_id = issues.issue_id  
                AND
                issue_message_ref.msg_id = message.msg_id 
                AND
                issues.repo_id = repo.repo_id 
                AND
                message.cntrb_id = '""" + cntrbID + """'
            GROUP BY
                repo.repo_id,
                repo.repo_name, 
                message.msg_timestamp
            ORDER BY
                message_month;
    """)

repolist2 = pd.read_sql(repo_query2, con=engine)

display(repolist2)

repolist2.dtypes
# Out:
#     repo_id repo_name message_month
# 0     26188     Loris    2011-11-01
# 1     26188     Loris    2011-12-01
# 2     26188     Loris    2012-01-01
# 3     26188     Loris    2012-02-01
# 4     26188     Loris    2012-04-01
# ..      ...       ...           ...
# 93    26188     Loris    2020-06-01
# 94    26188     Loris    2020-07-01
# 95    26188     Loris    2020-08-01
# 96    26188     Loris    2020-09-01
# 97    26188     Loris    2020-10-01
#
# [98 rows x 3 columns]
# repo_id                   int64
# repo_name                object
# message_month    datetime64[ns]
# dtype: object

# %%
###This calculates the percent of toxic messages per month and stores each month's average in an array###
toxic_messages_by_month_array = np.zeros(len(repolist2.message_month))
total_messages_by_month_array = np.zeros(len(repolist2.message_month))
monthYearLabel = []
i = 0
j = 0
while i < len(repolist2.message_month):
    month = repolist2.message_month[i]
    toxic_messages = 0
    total_messages = 0 #total messages for each month
    while repolist.message_month[j] == month:
        if repolist.average_sentiment[j] < 0:
            toxic_messages = toxic_messages + 1
        total_messages = total_messages + 1
        j = j + 1
        if j >= len(repolist.message_month):
            break
    toxic_messages_by_month_array[i] = toxic_messages
    total_messages_by_month_array[i] = total_messages
    print("toxic messages for month:", repolist2.message_month[i], ":",  toxic_messages, "total messages:", total_messages)
    monthYearLabel.append(repolist2.message_month[i].to_pydatetime().strftime("%B %Y"))
    i = i + 1
# Out:
# toxic messages for month: 2011-11-01 00:00:00 : 0 total messages: 1
# toxic messages for month: 2011-12-01 00:00:00 : 0 total messages: 1
# toxic messages for month: 2012-01-01 00:00:00 : 0 total messages: 2
# toxic messages for month: 2012-02-01 00:00:00 : 0 total messages: 1
# toxic messages for month: 2012-04-01 00:00:00 : 0 total messages: 1
# toxic messages for month: 2012-05-01 00:00:00 : 1 total messages: 7
# toxic messages for month: 2012-06-01 00:00:00 : 0 total messages: 2
# toxic messages for month: 2012-07-01 00:00:00 : 0 total messages: 2
# toxic messages for month: 2012-09-01 00:00:00 : 1 total messages: 1
# toxic messages for month: 2012-11-01 00:00:00 : 1 total messages: 4
# toxic messages for month: 2012-12-01 00:00:00 : 0 total messages: 1
# toxic messages for month: 2013-01-01 00:00:00 : 0 total messages: 2
# toxic messages for month: 2013-02-01 00:00:00 : 0 total messages: 4
# toxic messages for month: 2013-03-01 00:00:00 : 0 total messages: 2
# toxic messages for month: 2013-04-01 00:00:00 : 0 total messages: 3
# toxic messages for month: 2013-05-01 00:00:00 : 0 total messages: 2
# toxic messages for month: 2013-06-01 00:00:00 : 0 total messages: 1
# toxic messages for month: 2013-07-01 00:00:00 : 0 total messages: 2
# toxic messages for month: 2013-08-01 00:00:00 : 1 total messages: 4
# toxic messages for month: 2013-09-01 00:00:00 : 0 total messages: 1
# toxic messages for month: 2014-01-01 00:00:00 : 0 total messages: 2
# toxic messages for month: 2014-03-01 00:00:00 : 1 total messages: 2
# toxic messages for month: 2014-06-01 00:00:00 : 0 total messages: 9
# toxic messages for month: 2014-07-01 00:00:00 : 0 total messages: 1
# toxic messages for month: 2014-08-01 00:00:00 : 0 total messages: 1
# toxic messages for month: 2014-09-01 00:00:00 : 0 total messages: 5
# toxic messages for month: 2014-10-01 00:00:00 : 0 total messages: 6
# toxic messages for month: 2014-11-01 00:00:00 : 0 total messages: 6
# toxic messages for month: 2015-01-01 00:00:00 : 1 total messages: 8
# toxic messages for month: 2015-02-01 00:00:00 : 0 total messages: 9
# toxic messages for month: 2015-03-01 00:00:00 : 2 total messages: 14
# toxic messages for month: 2015-04-01 00:00:00 : 0 total messages: 12
# toxic messages for month: 2015-05-01 00:00:00 : 0 total messages: 1
# toxic messages for month: 2015-06-01 00:00:00 : 1 total messages: 7
# toxic messages for month: 2015-07-01 00:00:00 : 4 total messages: 20
# toxic messages for month: 2015-08-01 00:00:00 : 1 total messages: 7
# toxic messages for month: 2015-09-01 00:00:00 : 3 total messages: 5
# toxic messages for month: 2015-10-01 00:00:00 : 2 total messages: 15
# toxic messages for month: 2015-11-01 00:00:00 : 1 total messages: 20
# toxic messages for month: 2015-12-01 00:00:00 : 0 total messages: 11
# toxic messages for month: 2016-01-01 00:00:00 : 0 total messages: 14
# toxic messages for month: 2016-02-01 00:00:00 : 1 total messages: 7
# toxic messages for month: 2016-03-01 00:00:00 : 2 total messages: 22
# toxic messages for month: 2016-04-01 00:00:00 : 0 total messages: 5
# toxic messages for month: 2016-05-01 00:00:00 : 4 total messages: 11
# toxic messages for month: 2016-06-01 00:00:00 : 3 total messages: 30
# toxic messages for month: 2016-07-01 00:00:00 : 3 total messages: 23
# toxic messages for month: 2016-08-01 00:00:00 : 1 total messages: 13
# toxic messages for month: 2016-09-01 00:00:00 : 1 total messages: 35
# toxic messages for month: 2016-10-01 00:00:00 : 1 total messages: 25
# toxic messages for month: 2016-11-01 00:00:00 : 1 total messages: 13
# toxic messages for month: 2016-12-01 00:00:00 : 0 total messages: 8
# toxic messages for month: 2017-01-01 00:00:00 : 0 total messages: 8
# toxic messages for month: 2017-02-01 00:00:00 : 1 total messages: 6
# toxic messages for month: 2017-03-01 00:00:00 : 5 total messages: 16
# toxic messages for month: 2017-04-01 00:00:00 : 0 total messages: 17
# toxic messages for month: 2017-05-01 00:00:00 : 3 total messages: 36
# toxic messages for month: 2017-06-01 00:00:00 : 3 total messages: 52
# toxic messages for month: 2017-07-01 00:00:00 : 4 total messages: 53
# toxic messages for month: 2017-08-01 00:00:00 : 0 total messages: 24
# toxic messages for month: 2017-09-01 00:00:00 : 0 total messages: 8
# toxic messages for month: 2017-10-01 00:00:00 : 4 total messages: 56
# toxic messages for month: 2017-11-01 00:00:00 : 8 total messages: 57
# toxic messages for month: 2017-12-01 00:00:00 : 3 total messages: 32
# toxic messages for month: 2018-01-01 00:00:00 : 6 total messages: 53
# toxic messages for month: 2018-02-01 00:00:00 : 2 total messages: 35
# toxic messages for month: 2018-03-01 00:00:00 : 2 total messages: 28
# toxic messages for month: 2018-04-01 00:00:00 : 3 total messages: 20
# toxic messages for month: 2018-05-01 00:00:00 : 0 total messages: 28
# toxic messages for month: 2018-06-01 00:00:00 : 1 total messages: 27
# toxic messages for month: 2018-07-01 00:00:00 : 5 total messages: 53
# toxic messages for month: 2018-08-01 00:00:00 : 4 total messages: 61
# toxic messages for month: 2018-09-01 00:00:00 : 3 total messages: 37
# toxic messages for month: 2018-10-01 00:00:00 : 4 total messages: 47
# toxic messages for month: 2018-11-01 00:00:00 : 2 total messages: 42
# toxic messages for month: 2018-12-01 00:00:00 : 3 total messages: 54
# toxic messages for month: 2019-01-01 00:00:00 : 2 total messages: 39
# toxic messages for month: 2019-02-01 00:00:00 : 7 total messages: 60
# toxic messages for month: 2019-03-01 00:00:00 : 6 total messages: 46
# toxic messages for month: 2019-04-01 00:00:00 : 1 total messages: 25
# toxic messages for month: 2019-05-01 00:00:00 : 3 total messages: 77
# toxic messages for month: 2019-06-01 00:00:00 : 10 total messages: 153
# toxic messages for month: 2019-07-01 00:00:00 : 3 total messages: 45
# toxic messages for month: 2019-08-01 00:00:00 : 0 total messages: 16
# toxic messages for month: 2019-09-01 00:00:00 : 2 total messages: 25
# toxic messages for month: 2019-10-01 00:00:00 : 5 total messages: 49
# toxic messages for month: 2019-11-01 00:00:00 : 7 total messages: 155
# toxic messages for month: 2019-12-01 00:00:00 : 2 total messages: 29
# toxic messages for month: 2020-01-01 00:00:00 : 13 total messages: 96
# toxic messages for month: 2020-02-01 00:00:00 : 9 total messages: 96
# toxic messages for month: 2020-03-01 00:00:00 : 6 total messages: 61
# toxic messages for month: 2020-04-01 00:00:00 : 8 total messages: 78
# toxic messages for month: 2020-05-01 00:00:00 : 6 total messages: 37
# toxic messages for month: 2020-06-01 00:00:00 : 7 total messages: 80
# toxic messages for month: 2020-07-01 00:00:00 : 1 total messages: 60
# toxic messages for month: 2020-08-01 00:00:00 : 2 total messages: 42
# toxic messages for month: 2020-09-01 00:00:00 : 6 total messages: 39
# toxic messages for month: 2020-10-01 00:00:00 : 0 total messages: 2

# %%
length = len(toxic_messages_by_month_array)
lower = 0;
upper = min(29, length)
while(upper < len(toxic_messages_by_month_array)):
    if(lower > upper or lower >= length):
        break
    
    X = np.arange(len(toxic_messages_by_month_array[lower:upper]))

    fig = plt.figure(figsize=(30, 10))
    ax = fig.add_axes([0,0,1,1])
    ax.set_xticks(X)
    plt.ylabel("Message Count", fontsize=22)
    plt.xlabel("Month", fontsize=22)
    plt.title("Contributer " + str(cntrbID) + " Monthly Message Breakdown", fontsize=30)
    
    ax.set_xticklabels(monthYearLabel[lower:upper], rotation=80, fontsize=25)
    bars1 = ax.bar(X - 0.2, toxic_messages_by_month_array[lower:upper], color = 'b', width = 0.4)
    bars2 = ax.bar(X + 0.2, total_messages_by_month_array[lower:upper], color = 'g', width = 0.4)
    plt.legend([bars1, bars2], ["Toxic Message Count", "Total Message Count"], fontsize=25)
    for i in plt.bar_label(bars1):
        i.set_fontsize(27)
    for i in plt.bar_label(bars2):
        i.set_fontsize(27)
        
    lower = lower + 30
    upper = upper + min(30, length - lower)
